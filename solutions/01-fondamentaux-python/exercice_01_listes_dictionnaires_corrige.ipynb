# %% [markdown]
# # Corrigé Exercice 1 (Module 01) : Listes et dictionnaires

# %% [markdown]
# ## Partie 1

# %%
repondant_1 = {
    "age": 34,
    "secteur": "Commerce",
    "anciennete": 5.5,
    "satisfaction": 4,
}
print(repondant_1)
# Out:
# {'age': 34, 'secteur': 'Commerce', 'anciennete': 5.5, 'satisfaction': 4}

# %% [markdown]
# ## Partie 2

# %%
repondants = [
    {"age": 34, "secteur": "Commerce", "anciennete": 5.5, "satisfaction": 4},
    {"age": 28, "secteur": "Technologies", "anciennete": 2.0, "satisfaction": 5},
    {"age": 45, "secteur": "Industrie", "anciennete": 12.0, "satisfaction": 2},
    {"age": 51, "secteur": "Santé", "anciennete": 20.0, "satisfaction": 3},
    {"age": 39, "secteur": "Commerce", "anciennete": 8.0, "satisfaction": 4},
]

nb_repondants = len(repondants)
print(nb_repondants)

secteur_3e = repondants[2]["secteur"]  # index 2 = 3ème élément
print(secteur_3e)
# Out:
# 5
# Industrie

# %% [markdown]
# ## Partie 3

# %%
toutes_satisfactions = []
for r in repondants:
    toutes_satisfactions.append(r["satisfaction"])

print(toutes_satisfactions)

# Note : une compréhension de liste ferait la même chose en une ligne :
# toutes_satisfactions = [r["satisfaction"] for r in repondants]
# Out:
# [4, 5, 2, 3, 4]

# %% [markdown]
# ## Partie 4

# %%
for r in repondants:
    r["teletravail"] = True

print(repondants)
# Out:
# [{'age': 34, 'secteur': 'Commerce', 'anciennete': 5.5, 'satisfaction': 4, 'teletravail': True}, {'age': 28, 'secteur': 'Technologies', 'anciennete': 2.0, 'satisfaction': 5, 'teletravail': True}, {'age': 45, 'secteur': 'Industrie', 'anciennete': 12.0, 'satisfaction': 2, 'teletravail': True}, {'age': 51, 'secteur': 'Santé', 'anciennete': 20.0, 'satisfaction': 3, 'teletravail': True}, {'age': 39, 'secteur': 'Commerce', 'anciennete': 8.0, 'satisfaction': 4, 'teletravail': True}]
