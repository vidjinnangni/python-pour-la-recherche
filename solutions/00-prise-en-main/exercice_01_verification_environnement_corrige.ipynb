# %% [markdown]
# # Corrigé : Exercice 1 (Module 00)
#
# ## Vérification de l'environnement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Imports réussis !")
# Out:
# Imports réussis !

# %%
print("pandas :", pd.__version__)
print("numpy :", np.__version__)
# Out:
# pandas : 3.0.2
# numpy : 2.4.4

# %% [markdown]
# C'est tout pour cet exercice. L'essentiel était de réussir les imports sans erreur. Si c'est le cas, direction le [module 01](../../01-fondamentaux-python/).
