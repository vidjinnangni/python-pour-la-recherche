# %% [markdown]
# # Exercice 1 : Chargement et exploration d'un jeu de données
#
# **Objectif** : reprendre les bons réflexes d'exploration vus dans le notebook de cours, sur le même jeu de données (`entreprises_panel.csv`), en toute autonomie.
#
# Complétez les cellules à la place des `...`. N'hésitez pas à ajouter des cellules supplémentaires si besoin pour explorer.

# %% [markdown]
# ## Partie 1 : Charger les données
#
# Importez `pandas` sous son alias habituel, puis chargez `entreprises_panel.csv` dans une variable `df`.
#
# *Rappel : ce notebook est dans `modules/02-pandas-donnees/exercices/`, il faut donc remonter trois niveaux (`../../../`) pour atteindre la racine du repo avant de redescendre dans `assets/datasets/`.*

# %%
import ... as pd

df = pd.read_csv(...)

# %% [markdown]
# ## Partie 2 : Premier coup d'œil
#
# Affichez les 10 premières lignes du jeu de données (pas seulement 5).

# %%
# Votre code ici

# %% [markdown]
# ## Partie 3 : Dimensions et statistiques
#
# Répondez aux questions suivantes en écrivant le code correspondant (une cellule par question) :
#
# 1. Combien y a-t-il de lignes et de colonnes dans `df` ?
# 2. Quelle est la moyenne du chiffre d'affaires (`chiffre_affaires_keur`) sur l'ensemble du jeu de données ?
# 3. Quelle est la valeur maximale de `rentabilite` observée ?

# %%
# 1. Nombre de lignes et de colonnes

# %%
# 2. Moyenne du chiffre d'affaires

# %%
# 3. Valeur maximale de la rentabilité

# %% [markdown]
# ## Partie 4 : Types et valeurs manquantes
#
# Utilisez la méthode vue en cours qui affiche, pour chaque colonne, son type et son nombre de valeurs non manquantes. Répondez ensuite par une phrase (dans une cellule Markdown, ou en commentaire) : quelle colonne contient des valeurs manquantes, et combien ?

# %%
# Votre code ici

# %% [markdown]
# ## Partie 5 : Une colonne, plusieurs colonnes
#
# 1. Affichez uniquement la colonne `secteur` (le résultat doit être une `Series`, pas un `DataFrame`. Vérifiez avec `type()`).
# 2. Affichez les colonnes `entreprise_id`, `annee` et `secteur` ensemble (le résultat doit cette fois être un `DataFrame`).

# %%
# 1. Colonne secteur seule

# %%
# 2. Trois colonnes ensemble

# %% [markdown]
# Corrigé disponible dans [`solutions/02-pandas-donnees/`](../../../solutions/02-pandas-donnees/).
