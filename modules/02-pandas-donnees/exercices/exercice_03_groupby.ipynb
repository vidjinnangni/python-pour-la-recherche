# %% [markdown]
# # Exercice 3 : `groupby` et statistiques par groupe
#
# **Objectif** : utiliser `groupby` et `pivot_table` pour comparer des groupes d'entreprises entre eux, comme dans le notebook de cours.

# %%
import pandas as pd

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Une statistique, un groupe
#
# Calculez la rentabilité moyenne (`rentabilite`) par secteur (`secteur`). Quel secteur a la rentabilité moyenne la plus élevée ?
#
# *Indice : vous pouvez enchaîner `.groupby(...)`, `[...]`, `.mean()`, puis `.sort_values(...)` pour trier le résultat et repérer facilement le secteur en tête.*

# %%
# Votre code ici

# %% [markdown]
# ## Partie 2 : Plusieurs statistiques à la fois
#
# En une seule instruction utilisant `.agg()`, calculez pour chaque secteur : la moyenne, l'écart-type et le nombre d'observations (`count`) du chiffre d'affaires (`chiffre_affaires_keur`).

# %%
# Votre code ici

# %% [markdown]
# ## Partie 3 : Grouper sur deux variables
#
# Calculez l'effectif moyen (`effectifs`), groupé à la fois par `secteur` et par `teletravail`.

# %%
# Votre code ici

# %% [markdown]
# ## Partie 4 : Tableau croisé
#
# Construisez un tableau croisé (`pivot_table`) avec :
#
# - en lignes (`index`) : `secteur`
# - en colonnes (`columns`) : `teletravail`
# - valeurs : la moyenne de `chiffre_affaires_keur`
#
# Regardez le résultat : dans quel(s) secteur(s) l'écart entre télétravail et non-télétravail semble le plus marqué ? (Pas besoin de calcul supplémentaire, juste une observation visuelle du tableau — on ira plus loin avec de vrais tests statistiques au module 04.)

# %%
# Votre code ici

# %% [markdown]
# Corrigé disponible dans [`solutions/02-pandas-donnees/`](../../../solutions/02-pandas-donnees/).
