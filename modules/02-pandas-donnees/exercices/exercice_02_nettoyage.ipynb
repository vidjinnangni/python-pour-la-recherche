# %% [markdown]
# # Exercice 2 : Nettoyage des données
#
# **Objectif** : repérer et traiter des valeurs manquantes, des doublons, et vérifier les types ; les trois réflexes de nettoyage vus en cours.

# %%
import pandas as pd

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Repérer les valeurs manquantes
#
# Affichez le nombre de valeurs manquantes pour **chaque colonne** du jeu de données (une seule ligne de code, comme vu en cours).

# %%
# Votre code ici

# %% [markdown]
# ## Partie 2 : Traiter les valeurs manquantes
#
# La colonne concernée par des valeurs manquantes est `satisfaction_rh`.
#
# 1. Créez `df_sans_na`, une version de `df` où les lignes ayant une valeur manquante dans `satisfaction_rh` sont supprimées. Vérifiez qu'il n'y a plus de valeurs manquantes dans cette colonne.
# 2. Créez séparément `df_rempli`, une version de `df` (utilisez `.copy()` !) où les valeurs manquantes de `satisfaction_rh` sont remplacées par la **médiane** de la colonne plutôt que la moyenne (utilisez `.median()`).

# %%
# 1. Suppression des lignes avec valeur manquante
df_sans_na = ...

# Vérification

# %%
# 2. Remplacement par la médiane
df_rempli = df.copy()
mediane_satisfaction = ...
df_rempli["satisfaction_rh"] = ...

# Vérification

# %% [markdown]
# ## Partie 3 : Doublons
#
# 1. Combien de lignes sont des doublons exacts d'une autre ligne ?
# 2. Créez `df_propre`, une version de `df` sans ces doublons.
# 3. Combien de lignes reste-t-il dans `df_propre` ?

# %%
# 1. Nombre de doublons

# %%
# 2. Suppression des doublons
df_propre = ...

# %%
# 3. Nombre de lignes restantes

# %% [markdown]
# ## Partie 4 : Vérifier les types
#
# 1. Affichez le type de la colonne `effectifs`. Est-ce bien un type numérique ?
# 2. Utilisez `pd.to_numeric()` avec l'option `errors="coerce"` (vue en cours) sur la colonne `effectifs`. Combien de valeurs manquantes cela crée-t-il (s'il y en a) ? *Cette étape est un réflexe de sécurité à avoir même quand vous pensez que la colonne est déjà propre.*

# %%
# 1. Type de la colonne effectifs

# %%
# 2. Conversion et vérification

# %% [markdown]
# Corrigé disponible dans [`solutions/02-pandas-donnees/`](../../../solutions/02-pandas-donnees/).
