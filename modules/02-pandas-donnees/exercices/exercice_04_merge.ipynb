# %% [markdown]
# # Exercice 4 : Croiser deux jeux de données avec `merge`
#
# **Objectif** : pratiquer une jointure entre `entreprises_panel.csv` et un second petit jeu de données, en réfléchissant au bon choix du paramètre `how`.
#
# ## Contexte
#
# Une partie des entreprises du jeu de données a obtenu une certification ISO. On vous fournit cette information séparément (comme si elle provenait d'un autre fichier).

# %%
import pandas as pd

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

certifications = pd.DataFrame({
    "entreprise_id": ["E001", "E003", "E007", "E012", "E020", "E035", "E050"],
    "certification_iso": [True, True, False, True, True, False, True],
})
certifications

# %% [markdown]
# ## Partie 1 : Réfléchir avant de coder
#
# Avant d'écrire du code : si vous faites `df.merge(certifications, on="entreprise_id", how="left")`, combien de lignes attendez-vous dans le résultat, environ ? Et avec `how="inner"` ? Écrivez votre réponse en commentaire ou dans une cellule Markdown, **puis** vérifiez avec du code.

# %%
# Votre réponse (en commentaire), puis vérification par le code

# %% [markdown]
# ## Partie 2 : Jointure `left`
#
# Faites la jointure avec `how="left"`, dans une variable `df_avec_certif`. Combien de lignes ont une valeur manquante (`NaN`) dans `certification_iso` après cette jointure ? Pourquoi (répondez en une phrase) ?

# %%
df_avec_certif = ...

# Nombre de valeurs manquantes dans certification_iso

# %% [markdown]
# ## Partie 3 : Jointure `inner`
#
# Refaites la même jointure avec `how="inner"` cette fois, dans une variable `df_certif_seulement`. Combien de lignes obtenez-vous ? Combien d'entreprises **différentes** (en comptant les identifiants uniques) apparaissent dans ce résultat ?
#
# *Indice : `.nunique()` compte le nombre de valeurs différentes dans une colonne.*

# %%
df_certif_seulement = ...

# Nombre de lignes, puis nombre d'entreprises différentes

# %% [markdown]
# ## Partie 4 : Une comparaison simple
#
# En utilisant `df_avec_certif` (la jointure `left` de la partie 2), calculez le chiffre d'affaires moyen (`chiffre_affaires_keur`) selon la valeur de `certification_iso`, avec un `groupby`. Que remarquez-vous à propos des entreprises dont `certification_iso` est manquant (`NaN`) ? Apparaissent-elles dans ce résultat ?
#
# *Indice : par défaut, `groupby` ignore les groupes `NaN`.*

# %%
# Votre code ici

# %% [markdown]
# Corrigé disponible dans [`solutions/02-pandas-donnees/`](../../../solutions/02-pandas-donnees/).
