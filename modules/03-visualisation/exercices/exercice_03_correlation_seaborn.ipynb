# %% [markdown]
# # Exercice 3 : Visualiser une corrélation avec seaborn
#
# **Objectif** : utiliser seaborn pour explorer la relation entre deux variables numériques, avec et sans distinction de groupe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Nuage de points simple
#
# Avec `sns.scatterplot()`, tracez la relation entre `effectifs` (axe x) et `chiffre_affaires_keur` (axe y). Ajoutez un titre et des labels d'axes.

# %%
# Votre code ici

# %% [markdown]
# ## Partie 2 : Ajouter une dimension de couleur
#
# Refaites le même graphique, mais en coloriant les points selon `secteur` (paramètre `hue`, vu en cours). Que devient plus visible grâce à cette couleur, que vous ne pouviez pas voir dans la Partie 1 ?

# %%
# Votre code ici

# %% [markdown]
# ## Partie 3 : Matrice de corrélation
#
# 1. Calculez la matrice de corrélation (`.corr()`) des colonnes `effectifs`, `chiffre_affaires_keur`, `rentabilite` et `satisfaction_rh`.
# 2. Affichez-la sous forme de heatmap avec `sns.heatmap()`, avec les valeurs annotées (`annot=True`).
# 3. Quelle paire de variables a la corrélation la plus forte (en valeur absolue) ?

# %%
# 1. Matrice de corrélation

# %%
# 2. Heatmap

# %% [markdown]
# Corrigé disponible dans [`solutions/03-visualisation/`](../../../solutions/03-visualisation/).
