# %% [markdown]
# # Exercice 2 : Personnaliser un graphique
#
# **Objectif** : partir d'un graphique minimal et le rendre présentable.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Le graphique de départ (à ne pas reproduire tel quel !)
#
# Exécutez la cellule ci-dessous : c'est un graphique qui *fonctionne*, mais qui n'est clairement pas présentable. Repérez au moins 4 problèmes avant de continuer (listez-les en commentaire).

# %%
evolution = df.groupby("annee")["chiffre_affaires_keur"].mean()

fig, ax = plt.subplots()
ax.plot(evolution.index, evolution.values)
plt.show()

# Vos 4 problèmes repérés (en commentaire) :
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ## Partie 2 : Corriger le graphique
#
# Reproduisez ce graphique en corrigeant les problèmes identifiés. Au minimum, votre version corrigée doit avoir :
# - un titre
# - des labels sur les deux axes
# - une taille de figure plus grande et lisible (`figsize`)
# - des marqueurs sur chaque point (`marker=...`)

# %%
# Votre code ici

# %% [markdown]
# ## Partie 3 : Ajuster l'échelle
#
# Par défaut, matplotlib choisit automatiquement les bornes de l'axe Y. Forcez maintenant l'axe Y à démarrer à 0 (avec `ax.set_ylim(0, ...)`) plutôt que de laisser matplotlib zoomer sur la plage de valeurs.
#
# Comparez visuellement les deux versions (avec et sans `set_ylim`) : que remarquez-vous sur l'impression donnée par le graphique ?

# %%
# Votre code ici (reprenez le graphique de la partie 2, en ajoutant set_ylim)

# %% [markdown]
# Corrigé disponible dans [`solutions/03-visualisation/`](../../../solutions/03-visualisation/).
