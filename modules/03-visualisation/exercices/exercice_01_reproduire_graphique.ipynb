# %% [markdown]
# # Exercice 1 : Reproduire un graphique donné
#
# **Objectif** : partir d'une description et produire le graphique correspondant, en choisissant vous-même le bon type de graphique.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Quel type de graphique ?
#
# Pour chacune des trois demandes ci-dessous, répondez d'abord (en commentaire ou en Markdown) par le **type de graphique** le plus adapté (ligne, barres, histogramme, boxplot, nuage de points), avant d'écrire le code.
#
# **Demande A** : montrer comment se répartissent les effectifs (`effectifs`) de l'ensemble des entreprises.
#
# **Demande B** : comparer le nombre d'entreprises (`count`) par secteur (`secteur`).
#
# **Demande C** : montrer la relation entre la rentabilité (`rentabilite`) et la satisfaction RH (`satisfaction_rh`).

# %%
# Réponse A : type de graphique = ...

# %%
# Réponse B : type de graphique = ...

# %%
# Réponse C : type de graphique = ...

# %% [markdown]
# ## Partie 2 : Produire les graphiques
#
# Produisez maintenant les trois graphiques correspondants, avec `matplotlib` (`fig, ax = plt.subplots()`), chacun avec un titre et des labels d'axes.
#
# *Indice pour la demande B : vous aurez besoin de compter le nombre de lignes par secteur avant de tracer ; une méthode vue au module 02 (`groupby` + `.size()`, ou `.value_counts()`) sera utile.*

# %%
# Graphique A

# %%
# Graphique B

# %%
# Graphique C

# %% [markdown]
# Corrigé disponible dans [`solutions/03-visualisation/`](../../../solutions/03-visualisation/).
