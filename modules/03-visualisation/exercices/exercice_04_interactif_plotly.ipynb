# %% [markdown]
# # Exercice 4 : Créer un graphique interactif avec plotly
#
# **Objectif** : produire un graphique interactif avec `plotly.express`, en exploitant ce que l'interactivité apporte de plus par rapport à un graphique statique.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv("../../../assets/datasets/entreprises_panel.csv")

# %% [markdown]
# ## Partie 1 : Un graphique en barres interactif
#
# Calculez le chiffre d'affaires moyen (`chiffre_affaires_keur`) par secteur, puis affichez-le avec `px.bar()`. Donnez-lui un titre.
#
# *Indice : `px.bar()` attend un DataFrame ou des listes en x/y. Vous pouvez utiliser `.reset_index()` après un `groupby` pour obtenir un DataFrame simple à passer à plotly.*

# %%
# Votre code ici

# %% [markdown]
# ## Partie 2 : Un nuage de points avec `hover_data`
#
# Créez un `px.scatter()` de `effectifs` (x) contre `rentabilite` (y), colorié par `teletravail`, avec `hover_data=["entreprise_id", "annee", "secteur"]` pour enrichir l'info au survol.
#
# Survolez quelques points : identifiez une entreprise qui vous semble atypique (par exemple, une rentabilité très élevée ou très basse pour son niveau d'effectifs) et notez son `entreprise_id`.

# %%
# Votre code ici

# %% [markdown]
# ## Partie 3 : Une ligne interactive dans le temps
#
# Calculez la satisfaction RH moyenne (`satisfaction_rh`) par année et par valeur de télétravail, puis affichez le résultat avec `px.line()`, avec une couleur différente par valeur de `teletravail`.
#
# *Indice : comme pour l'exercice précédent, `.reset_index()` après un `groupby` sur deux colonnes vous donnera un DataFrame directement utilisable par plotly, avec `color="teletravail"`.*

# %%
# Votre code ici

# %% [markdown]
# Corrigé disponible dans [`solutions/03-visualisation/`](../../../solutions/03-visualisation/).
