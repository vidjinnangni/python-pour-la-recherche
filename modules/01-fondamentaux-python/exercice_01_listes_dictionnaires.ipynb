# %% [markdown]
# # Exercice 1 : Listes et dictionnaires
#
# **Objectif** : manipuler des listes et des dictionnaires en structurant une petite base de répondants fictifs à une enquête.
#
# Complétez les cellules ci-dessous à la place des `...`. N'hésitez pas à ajouter des `print()` pour vérifier vos résultats au fur et à mesure.

# %% [markdown]
# ## Partie 1 : Structurer un répondant
#
# Créez un dictionnaire `repondant_1` représentant un répondant fictif, avec les clés suivantes :
# - `"age"` : 34
# - `"secteur"` : "Commerce"
# - `"anciennete"` : 5.5
# - `"satisfaction"` : 4 (note sur 5)

# %%
repondant_1 = ...

# %% [markdown]
# ## Partie 2 : Une liste de répondants
#
# On vous donne une liste de 5 répondants déjà structurée. Affichez le nombre total de répondants, puis le secteur du 3ème répondant de la liste (attention aux index, qui commencent à 0).

# %%
repondants = [
    {"age": 34, "secteur": "Commerce", "anciennete": 5.5, "satisfaction": 4},
    {"age": 28, "secteur": "Technologies", "anciennete": 2.0, "satisfaction": 5},
    {"age": 45, "secteur": "Industrie", "anciennete": 12.0, "satisfaction": 2},
    {"age": 51, "secteur": "Santé", "anciennete": 20.0, "satisfaction": 3},
    {"age": 39, "secteur": "Commerce", "anciennete": 8.0, "satisfaction": 4},
]

# Nombre total de répondants
nb_repondants = ...
print(nb_repondants)

# Secteur du 3ème répondant de la liste
secteur_3e = ...
print(secteur_3e)
# Out:
# Ellipsis
# Ellipsis

# %% [markdown]
# ## Partie 3 : Extraire une information de tous les répondants
#
# Construisez la liste `toutes_satisfactions` contenant uniquement les valeurs de `"satisfaction"` de chaque répondant (vous devriez obtenir `[4, 5, 2, 3, 4]`).
#
# *Indice : une boucle `for` qui parcourt `repondants`, en ajoutant à chaque tour la valeur voulue dans une liste initialement vide.*

# %%
toutes_satisfactions = []
# Votre code ici (boucle for)

print(toutes_satisfactions)
# Out:
# []

# %% [markdown]
# ## Partie 4 : Ajouter une information
#
# Ajoutez la clé `"teletravail"` (valeur `True` ou `False`, au choix) à chacun des 5 répondants de la liste `repondants`, avec une boucle `for`. Affichez ensuite `repondants` pour vérifier.

# %%
# Votre code ici

print(repondants)
# Out:
# [{'age': 34, 'secteur': 'Commerce', 'anciennete': 5.5, 'satisfaction': 4}, {'age': 28, 'secteur': 'Technologies', 'anciennete': 2.0, 'satisfaction': 5}, {'age': 45, 'secteur': 'Industrie', 'anciennete': 12.0, 'satisfaction': 2}, {'age': 51, 'secteur': 'Santé', 'anciennete': 20.0, 'satisfaction': 3}, {'age': 39, 'secteur': 'Commerce', 'anciennete': 8.0, 'satisfaction': 4}]

# %% [markdown]
# Corrigé disponible dans [`solutions/01-fondamentaux-python/`](../../../solutions/01-fondamentaux-python/). Essayez de résoudre d'abord avant de consulter la solution !
