# %% [markdown]
# # Exercice 2 : Boucles et conditions
#
# **Objectif** : filtrer et catégoriser des données à l'aide de boucles et de conditions.
#
# On reprend une liste d'effectifs d'entreprises fictives.

# %%
effectifs_entreprises = [8, 45, 230, 12, 95, 340, 28, 5, 180, 60]

# %% [markdown]
# ## Partie 1 : Filtrer selon un seuil
#
# Construisez la liste `pme` contenant uniquement les effectifs strictement inférieurs à 250 (définition simplifiée d'une PME pour cet exercice).
#
# Faites-le d'abord avec une boucle `for` classique.

# %%
pme = []
# Votre code ici (boucle for + condition)

print(pme)
# Out:
# []

# %% [markdown]
# ## Partie 2 : Même chose, en compréhension de liste
#
# Refaites l'exercice précédent en une seule ligne, avec une compréhension de liste. Le résultat doit être identique.

# %%
pme_v2 = ...
print(pme_v2)
print(pme == pme_v2)  # doit afficher True si vos deux résultats sont identiques
# Out:
# Ellipsis
# False

# %% [markdown]
# ## Partie 3 : Catégoriser chaque entreprise
#
# Pour chaque effectif de `effectifs_entreprises`, affichez une phrase indiquant sa catégorie, selon la règle suivante :
# - effectif < 10 : "Micro-entreprise"
# - 10 <= effectif < 50 : "Petite entreprise"
# - 50 <= effectif < 250 : "Moyenne entreprise"
# - effectif >= 250 : "Grande entreprise"
#
# *Indice : une boucle `for` avec un `if` / `elif` / `elif` / `else` à l'intérieur.*

# %%
for effectif in effectifs_entreprises:
    # Votre code ici
    ...

# %% [markdown]
# ## Partie 4 : Compter par catégorie
#
# En réutilisant la logique de la partie 3, comptez cette fois le nombre d'entreprises dans chaque catégorie, et stockez le résultat dans un dictionnaire `compteur` de la forme :
# ```python
# {"Micro-entreprise": ..., "Petite entreprise": ..., "Moyenne entreprise": ..., "Grande entreprise": ...}
# ```
#
# *Indice : initialisez le dictionnaire avec toutes les catégories à 0, puis incrémentez (`compteur["Petite entreprise"] += 1`) au fil de la boucle.*

# %%
compteur = {"Micro-entreprise": 0, "Petite entreprise": 0, "Moyenne entreprise": 0, "Grande entreprise": 0}

# Votre code ici

print(compteur)
# Out:
# {'Micro-entreprise': 0, 'Petite entreprise': 0, 'Moyenne entreprise': 0, 'Grande entreprise': 0}

# %% [markdown]
# Corrigé disponible dans [`solutions/01-fondamentaux-python/`](../../../solutions/01-fondamentaux-python/).
