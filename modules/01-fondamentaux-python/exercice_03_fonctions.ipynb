# %% [markdown]
# # Exercice 3 : Écrire une fonction réutilisable
#
# **Objectif** : écrire, tester et réutiliser une fonction Python, pour calculer une moyenne pondérée.

# %% [markdown]
# ## Partie 1 : Une première version simple
#
# Écrivez une fonction `moyenne(valeurs)` qui prend une liste de nombres et retourne leur moyenne simple (non pondérée).
#
# *Rappel : la moyenne est la somme des valeurs divisée par leur nombre. Les fonctions `sum()` et `len()` de Python vous seront utiles.*

# %%
def moyenne(valeurs):
    ...

# Test : doit afficher 3.0
print(moyenne([1, 2, 3, 4, 5]))
# Out:
# None

# %% [markdown]
# ## Partie 2 : Ajouter des poids
#
# Écrivez maintenant une fonction `moyenne_ponderee(valeurs, poids)`, qui prend deux listes de même longueur (une de valeurs, une de poids associés) et retourne la moyenne pondérée.
#
# Formule : $\dfrac{\sum (valeur_i \times poids_i)}{\sum poids_i}$
#
# *Indice : la fonction `zip(valeurs, poids)` permet de parcourir les deux listes en parallèle, élément par élément.*

# %%
def moyenne_ponderee(valeurs, poids):
    ...

# Test : si tous les poids valent 1, le résultat doit être identique à une moyenne simple
print(moyenne_ponderee([1, 2, 3, 4, 5], [1, 1, 1, 1, 1]))  # doit afficher 3.0

# Test avec des poids différents
print(moyenne_ponderee([4, 5, 2, 3], [1, 2, 1, 1]))  # doit afficher 3.8
# Out:
# None
# None

# %% [markdown]
# ## Partie 3 : Gérer un cas limite
#
# Que se passe-t-il si vous appelez `moyenne_ponderee([], [])` (deux listes vides) ? Testez-le.

# %%
# Votre test ici

# %% [markdown]
# Vous devriez obtenir une erreur (`ZeroDivisionError`, la somme des poids valant 0). Modifiez votre fonction `moyenne_ponderee` pour qu'elle retourne `None` (plutôt que de planter) si la liste `poids` est vide ou si la somme des poids vaut 0.
#
# *Indice : ajoutez une condition tout au début de la fonction, avant le calcul.*

# %%
def moyenne_ponderee(valeurs, poids):
    # Votre code ici : gérer le cas limite, puis reprendre le calcul de la partie 2
    ...

print(moyenne_ponderee([], []))              # doit afficher None
print(moyenne_ponderee([4, 5, 2, 3], [1, 2, 1, 1]))  # doit toujours afficher 3.8
# Out:
# None
# None

# %% [markdown]
# ## Partie 4 : Réutiliser sur un cas concret
#
# En reprenant la liste de répondants ci-dessous, calculez la satisfaction moyenne pondérée en utilisant l'ancienneté de chaque répondant comme poids (un répondant plus ancien "compte" davantage dans la moyenne).

# %%
repondants = [
    {"satisfaction": 4, "anciennete": 5.5},
    {"satisfaction": 5, "anciennete": 2.0},
    {"satisfaction": 2, "anciennete": 12.0},
    {"satisfaction": 3, "anciennete": 20.0},
]

# Construisez les deux listes nécessaires, puis appelez votre fonction
satisfactions = ...
anciennetes = ...

resultat = moyenne_ponderee(satisfactions, anciennetes)
print(f"Satisfaction moyenne pondérée : {resultat:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 13
#       9 satisfactions = ...
#      10 anciennetes = ...
#      11
#      12 resultat = moyenne_ponderee(satisfactions, anciennetes)
# ---> 13 print(f"Satisfaction moyenne pondérée : {resultat:.2f}")
#
# TypeError: unsupported format string passed to NoneType.__format__

# %% [markdown]
# Corrigé disponible dans [`solutions/01-fondamentaux-python/`](../../../solutions/01-fondamentaux-python/).
