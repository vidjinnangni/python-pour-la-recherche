# %% [markdown]
# # Exercice 1 : Vérification de l'environnement
#
# Cet exercice a pour objectif de vérifier que votre environnement Python est prêt pour la suite du cours, en important les bibliothèques principales que nous utiliserons.
#
# **Consigne** : complétez la cellule ci-dessous en remplaçant les `...` pour importer `pandas`, `numpy` et `matplotlib.pyplot`, avec leurs alias habituels (`pd`, `np`, `plt`).

# %%
# TODO : complétez les imports suivants
import ... as pd
import ... as np
import ...pyplot as plt

print("Imports réussis !")

# %% [markdown]
# **Consigne 2** : si l'import a fonctionné, exécutez la cellule suivante sans la modifier. Elle affiche les versions installées. Comparez-les à celles de `requirements.txt` à la racine du repo (ce n'est pas grave si elles diffèrent légèrement).

# %%
print("pandas :", pd.__version__)
print("numpy :", np.__version__)

# %% [markdown]
# Si les deux cellules se sont exécutées sans erreur, votre environnement est prêt. Si vous obtenez une erreur `ModuleNotFoundError`, retournez au [README principal du repo](../../README.md), section "Installation" et vérifiez que vous avez bien activé votre environnement virtuel (`venv` ou `conda`) avant de lancer Jupyter.
#
# Le corrigé est disponible dans [`solutions/00-prise-en-main/`](../../solutions/00-prise-en-main/).
